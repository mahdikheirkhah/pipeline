# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# We will use a tiny dataset for this exercise that we will generate by ourselves:
#
# ```python
# X_train = np.array([[ 1., -1.,  2.],
#                      [ 2.,  0.,  0.],
#                      [ 0.,  1., -1.]])
# ```

# %%
X_train = np.array([[ 1., -1.,  2.],
                     [ 2.,  0.,  0.],
                     [ 0.,  1., -1.]])

# %% [markdown]
# 1. Fit the `StandardScaler` on the data and scale X_train using `fit_transform`. Compute the `mean` and `std` on `axis 0`.

# %%
standard_scaler = StandardScaler()
X_train_standard_scale = standard_scaler.fit_transform(X_train)
print(np.mean(X_train_standard_scale, axis = 0))
print(np.std(X_train_standard_scale, axis = 0))
# Out:
# [0. 0. 0.]
# [1. 1. 1.]

# %% [markdown]
# 2. Scale the test set using the `StandardScaler` fitted on the train set.
#
# ```python
# X_test = np.array([[ 2., -1.,  1.],
#                      [ 3.,  3.,  -1.],
#                      [ 1.,  1., 1.]])

# %%
X_test_standard_scale = standard_scaler.fit_transform(X_test)
print(np.mean(X_test_standard_scale, axis = 0))
print(np.std(X_tr_standard_scale, axis = 0))
